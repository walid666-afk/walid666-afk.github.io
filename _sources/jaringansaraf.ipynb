# %% [markdown]
# # **JARINGAN SYARAF TIRUAN**

# %% [markdown]
# ##**Classification Data Mahasiswa**
#
#
# *   Data Mahasiswa
#
#
# ![image.png](data:image/png;base64,...)
#
# *   Normalisasi Data
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Jadi disini kita mendapatkan data normalisasi dari rumus diatas yaitu sebagai berikut :
#
#
#
# 	Nilai Terkecil
# 	  IPK        =	2.8
# 	  Jumlah SKS =	75
#
# 	Nilai Terbesar
# 	  IPK        =	3.9
# 	  Jumlah SKS =	150
#
# 	Tidak =	0.0
# 	Ya    =	1.0
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# Sebelum pelatihan, harus ditentukan terlebih dahulu stopping conditionnya. Misalnya dihentikan jika error telah mencapai 0,40 atau iterasinya telah mencapai 10.
#
#
#
# 1. Step 0
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#     Menentukan bobot secara acak
# 		  V11 =	0.375
# 		  V21 =	0.951
# 		  V12 =	0.732
# 		  V22 =	0.599
# 		  W11 =	0.156
# 		  W21 =	0.156
#
#
#     Menentukan bias secara acak
# 		  V01 =	0.058
# 		  V02 =	0.866
# 		  W01 =	0.601
#
#
# 2. Step 1
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
#
#     Menghitung semua output/keluaran di unit tersembunyi
# 		  Z_in11 =	0.867
# 		  Z_in12 =	0.350
# 		  Z_in13 =	1.384
# 		  Z_in14 =	0.058
# 		  Z_in21 =	1.691
# 		  Z_in22 =	1.185
# 		  Z_in23 =	2.197
# 		  Z_in24 =	0.866
#
# 		  Z11 =	0.704
# 		  Z12 =	0.587
# 		  Z13 =	0.800
# 		  Z14 =	0.514
# 		  Z21 =	0.844
# 		  Z22 =	0.766
# 		  Z23 =	0.900
# 		  Z24 =	0.704
#
#
# 3. Step 2
#
#
#
#     Menghitung semua output/keluaran jaringan di unit Y
# 		  y_in11 =	0.843
# 		  y_in12 =	0.812
# 		  y_in13 =	0.866
# 		  y_in14 =	0.791
#
# 		  y11 =	0.699
# 		  y12 =	0.693
# 		  y13 =	0.704
# 		  y14 =	0.688
#
#
# 4. Step 3
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#     Memeriksa stopping, jika telah memenuhi maka tidak perlu melanjutkan ke step 4 (selesai)
# 		  MSE =	0.57
#
#
# 5. Step 4
#
#
# ![image.png](data:image/png;base64,...)
#
#
#
# ![image.png](data:image/png;base64,...)
#
#
#   **α = 0,2**
#
#
#     Menghitung kesalahan/error disetiap unit keluaran Y
# 		  delta_1 =	0.063
#
#
#     Menghitung suku perubahan bobot Wjk
# 		  delta_W01 =	0.013
# 		  delta_W11 =	0.009
# 		  delta_W21 =	0.011
